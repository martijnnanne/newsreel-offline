# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
results = pd.read_csv('test_results_2', delimiter=',', header=None, names=['ranker', 'day', 'domain','correct','total', 'precision'])
domains = results['domain']
domains = domains.unique()
rankers = results['ranker']
rankers = rankers.unique()

# %%
results
# Out:
#                ranker  day  domain  correct  total  precision
# 0     session_seqrank    1    1677    13241  26287   0.503709
# 1     session_seqrank    1    3336        0      2   0.000000
# 2     session_seqrank    1     596        0      0   0.000000
# 3     session_seqrank    1     418     2986   8673   0.344287
# 4     session_seqrank    1   35774    18769  60688   0.309270
# 5     session_seqrank    1     694       56    546   0.102564
# 6     session_seqrank    1    2522        0      0   0.000000
# 7     session_seqrank    1   13554        0      0   0.000000
# 8     session_seqrank    2    1677    10044  23333   0.430463
# 9     session_seqrank    2    3336        0      1   0.000000
# 10    session_seqrank    2     596        0      0   0.000000
# 11    session_seqrank    2     418     3529   8958   0.393950
# 12    session_seqrank    2   35774     8971  52025   0.172436
# 13    session_seqrank    2     694       81    601   0.134775
# 14    session_seqrank    2    2522        0      0   0.000000
# 15    session_seqrank    2   13554        0      0   0.000000
# 16    session_seqrank    3    1677     5799  17553   0.330371
# 17    session_seqrank    3    3336        0      0   0.000000
# 18    session_seqrank    3     596        0      0   0.000000
# 19    session_seqrank    3     418     3005   8912   0.337186
# 20    session_seqrank    3   35774     7225  43680   0.165408
# 21    session_seqrank    3     694       68    537   0.126629
# 22    session_seqrank    3    2522        0      0   0.000000
# 23    session_seqrank    3   13554        0      0   0.000000
# 24    session_seqrank    4    1677     5555  16891   0.328873
# 25    session_seqrank    4    3336        0      1   0.000000
# 26    session_seqrank    4     596        0      0   0.000000
# 27    session_seqrank    4     418     5024  11399   0.440740
# 28    session_seqrank    4   35774     5192  49312   0.105289
# 29    session_seqrank    4     694       62    444   0.139640
# ...               ...  ...     ...      ...    ...        ...
# 1266         coocrank   24     596        0      0   0.000000
# 1267         coocrank   24    1677     3153  13567   0.232402
# 1268         coocrank   24   35774    22019  55734   0.395073
# 1269         coocrank   24   13554        0      0   0.000000
# 1270         coocrank   24     418     1206   5100   0.236471
# 1271         coocrank   24    3336        1      3   0.333333
# 1272         coocrank   25     694       56    447   0.125280
# 1273         coocrank   25    2522        0      0   0.000000
# 1274         coocrank   25     596        0      0   0.000000
# 1275         coocrank   25    1677     2924  14473   0.202031
# 1276         coocrank   25   35774    17961  45008   0.399062
# 1277         coocrank   25   13554        0      0   0.000000
# 1278         coocrank   25     418     1407   5066   0.277734
# 1279         coocrank   25    3336        0      2   0.000000
# 1280         coocrank   26     694       83    463   0.179266
# 1281         coocrank   26    2522        0      0   0.000000
# 1282         coocrank   26     596        0      0   0.000000
# 1283         coocrank   26    1677     5770  16744   0.344601
# 1284         coocrank   26   35774    22308  58087   0.384045
# 1285         coocrank   26   13554        0      0   0.000000
# 1286         coocrank   26     418     1975   6003   0.329002
# 1287         coocrank   26    3336        1      2   0.500000
# 1288         coocrank   27     694       92    422   0.218009
# 1289         coocrank   27    2522        0      0   0.000000
# 1290         coocrank   27     596        0      0   0.000000
# 1291         coocrank   27    1677     3778  12051   0.313501
# 1292         coocrank   27   35774    22237  54174   0.410474
# 1293         coocrank   27   13554        0      0   0.000000
# 1294         coocrank   27     418     1510   3975   0.379874
# 1295         coocrank   27    3336        0      3   0.000000
#
# [1296 rows x 6 columns]

# %%
results.query('ranker == "contentrank" & domain == 35774')
# Out:
#           ranker  day  domain  correct  total  precision
# 436  contentrank    1   35774     5960  60688   0.098207
# 444  contentrank    2   35774     7155  52025   0.137530
# 452  contentrank    3   35774     8125  43680   0.186012
# 460  contentrank    4   35774     5728  49312   0.116158
# 468  contentrank    5   35774     4025  53633   0.075047
# 476  contentrank    6   35774     4128  58831   0.070167
# 484  contentrank    7   35774     2259  59601   0.037902
# 492  contentrank    8   35774     3728  59071   0.063110
# 500  contentrank    9   35774     1362  53321   0.025543
# 508  contentrank   10   35774      914  49630   0.018416
# 516  contentrank   11   35774      833  65869   0.012646
# 524  contentrank   12   35774     1296  57812   0.022417
# 532  contentrank   13   35774      369  66981   0.005509
# 540  contentrank   14   35774      764  65002   0.011753
# 548  contentrank   15   35774      561  43403   0.012925
# 556  contentrank   16   35774      109  53466   0.002039
# 564  contentrank   17   35774      719  52043   0.013815
# 572  contentrank   18   35774      446  46821   0.009526
# 580  contentrank   19   35774      412  47677   0.008641
# 588  contentrank   20   35774      660  60094   0.010983
# 596  contentrank   21   35774     4481  87687   0.051102
# 604  contentrank   22   35774     2179  48911   0.044550
# 612  contentrank   23   35774      553  49515   0.011168
# 620  contentrank   24   35774      168  55734   0.003014
# 628  contentrank   25   35774      206  45008   0.004577
# 636  contentrank   26   35774      248  58087   0.004269
# 644  contentrank   27   35774      379  54174   0.006996

# %%
i = 0
for ranker in rankers:
    i = i +1
    fig = plt.figure(figsize=(6,4))
    ax  = fig.add_subplot(111)
    ax.set_title(ranker)
#     plt.title(ranker)
    for domain in domains:
        subresults = results.query('ranker == "%s" & domain == %s' % (ranker,domain))
        days = subresults['day']
        precision = subresults['precision']
        ax.set_position([0.1,0.1,0.5,0.8])
        ax.plot(days, precision)
        ax.legend(domains, loc="upper left", bbox_to_anchor=(1,1))
        fig.savefig('ranker_%s_test1.png' % i)

# %%
i=0
for domain in domains:
    i = i + 1
    plt.figure()
    plt.title(domain)
    for ranker in rankers:
        subresults = results.query('ranker == "%s" & domain == %s' % (ranker,domain))
        days = subresults['day']
        precision = subresults['precision']
        plt.plot(days, precision)
        plt.legend(rankers, loc="upper left", bbox_to_anchor=(1,1))
        plt.savefig('domain_%s_test1.png' % i)
