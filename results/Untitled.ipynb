# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('first_test.csv', delimiter=',', header=None, names=['ranker', 'day', 'domain', 'precision'])
domains = results['domain']

# %%
results
# Out:
#          ranker  day  domain  precision
# 0   contentrank    1    3336   0.000000
# 1   contentrank    1     418   0.001268
# 2   contentrank    1    2522   0.000000
# 3   contentrank    1   35774   0.105243
# 4   contentrank    1     694   0.000000
# 5   contentrank    1    1677   0.013124
# 6   contentrank    1   13554   0.000000
# 7   contentrank    2    3336   0.000000
# 8   contentrank    2     418   0.008484
# 9   contentrank    2    2522   0.000000
# 10  contentrank    2   35774   0.137934
# 11  contentrank    2     694   0.000000
# 12  contentrank    2    1677   0.017443
# 13  contentrank    2   13554   0.000000
# 14  contentrank    3    3336   0.000000
# 15  contentrank    3     418   0.028276
# 16  contentrank    3    2522   0.000000
# 17  contentrank    3   35774   0.184409
# 18  contentrank    3     694   0.000000
# 19  contentrank    3    1677   0.009058
# 20  contentrank    3   13554   0.000000
# 21     coocrank    1    3336   0.000000
# 22     coocrank    1     418   0.263692
# 23     coocrank    1    2522   0.000000
# 24     coocrank    1   35774   0.314659
# 25     coocrank    1     694   0.098901
# 26     coocrank    1    1677   0.463157
# 27     coocrank    1   13554   0.000000
# 28     coocrank    2    3336   0.000000
# 29     coocrank    2     418   0.381335
# ..          ...  ...     ...        ...
# 54      poprank    2    1677   0.166631
# 55      poprank    2   13554   0.000000
# 56      poprank    3    3336   0.000000
# 57      poprank    3     418   0.266382
# 58      poprank    3    2522   0.000000
# 59      poprank    3   35774   0.115705
# 60      poprank    3     694   0.026071
# 61      poprank    3    1677   0.239047
# 62      poprank    3   13554   0.000000
# 63      seqrank    1    3336   0.000000
# 64      seqrank    1     418   0.307621
# 65      seqrank    1    2522   0.000000
# 66      seqrank    1   35774   0.267071
# 67      seqrank    1     694   0.181319
# 68      seqrank    1    1677   0.487732
# 69      seqrank    1   13554   0.000000
# 70      seqrank    2    3336   0.000000
# 71      seqrank    2     418   0.396182
# 72      seqrank    2    2522   0.000000
# 73      seqrank    2   35774   0.141317
# 74      seqrank    2     694   0.214642
# 75      seqrank    2    1677   0.439849
# 76      seqrank    2   13554   0.000000
# 77      seqrank    3    3336   0.000000
# 78      seqrank    3     418   0.339430
# 79      seqrank    3    2522   0.000000
# 80      seqrank    3   35774   0.126122
# 81      seqrank    3     694   0.379888
# 82      seqrank    3    1677   0.365351
# 83      seqrank    3   13554   0.000000
#
# [84 rows x 4 columns]

# %%
results.query('ranker == "contentrank" & domain == 35774')
# Out:
#          ranker  day  domain  precision
# 3   contentrank    1   35774   0.105243
# 10  contentrank    2   35774   0.137934
# 17  contentrank    3   35774   0.184409

# %%
for domain in domains.unique():
    results.query('ranker == "contentrank" & domain == 35774')
# Out:
# 3336
# 418
# 2522
# 35774
# 694
# 1677
# 13554
